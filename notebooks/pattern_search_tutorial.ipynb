# %%
import pandas as pd, numpy as np
import re
import seaborn as sns
import sys  
sys.path.insert(1, '../src')
from step_serializer import StepSerializer
from step_pattern_searcher import StepPatternSearcher

# %% [markdown]
# # Stepchart Data
#
# Begin by reading in a data frame as output by the ``sss_crawler.py`` script found in the ``src`` folder of the NLPump directory.

# %%
df = pd.read_csv('../data/PRIME-PHOENIX.csv', index_col=0)
df.head()
# Out:
#   Song Title Step Type  Difficulty  \
# 0    Nemesis         S           4
# 1    Nemesis         S           7
# 2    Nemesis         S          10
# 3    Nemesis         S          16
# 4    Nemesis         S          18
#
#                                                Steps
# 0  6.071:Z-6.821:Z-7.571:C-8.321:C-9.071:Q-9.821:...
# 1  6.071:z1-6.634:z0-6.821:c1-7.384:c0-7.571:S-8....
# 2  6.071:z1-6.821:e1z-7.196:z0e0-7.571:S-8.321:E-...
# 3  4.571:Q-4.758:C-4.946:Z-5.134:E-5.321:Q-5.508:...
# 4  6.071:z1-6.821:s1e1z-7.196:z0s0e0-7.571:c1-8.1...

# %% [markdown]
# Now separate out the single and double charts, as searching for double patterns within a single chart will result in dictionary key errors (this will be fixed eventually).

# %%
df_s =  df.loc[df['Step Type'] == 'S', :].copy()
df_d = df.loc[df['Step Type'] == 'D', :].copy()

# %% [markdown]
# # Searching for Patterns
#
# Now we can start searching for patterns. Create a StepPatternSearcher object and then apply its search function to the data frame rows as illustrated by the examples below.

# %%
searcher = StepPatternSearcher()

# %% [markdown]
# ### Pattern Search Example (Single)

# %%
pattern = 'QSC-ZSE-QSC' # alternating diagonal triples
col = f'timestamps ({pattern})'

# The search function requires the step type and chart as inputs as well as the pattern,
# so we apply the following lambda function to search each stepchart in the data frame.
df_s[col] = df_s.apply(lambda row: searcher.search(
    row['Step Type'],
    row['Steps'],
    pattern,
    0,
    1
), axis=1)

# Create new column showing timestamps where pattern is found.
df_s.loc[
    df_s[col].apply(len) > 0, # exclude stepcharts with 0 matches.
    ['Song Title', 'Step Type', 'Difficulty', col]
].sort_values('Difficulty')
# Out:
#                                   Song Title Step Type  Difficulty  \
# 731             Rock the house - SHORT CUT -         S          15
# 2152         The End of the World ft. Skizzo         S          16
# 512                              Smile Diary         S          16
# 2282               BBoom BBoom - FULL SONG -         S          17
# 1409                            Obliteration         S          18
# 2822                                 GOODTEK         S          18
# 635                        Idealized Romance         S          18
# 73                          You Got Me Crazy         S          18
# 331           Ineffective Boss Without Power         S          18
# 513                              Smile Diary         S          19
# 177                        Allegro Piu Mosso         S          19
# 2419                             Euphorianic         S          19
# 1134                      Nakakapagpabagabag         S          19
# 2392                              Versailles         S          19
# 1376                Death Moon - SHORT CUT -         S          19
# 2886                                    PUPA         S          19
# 2896                                  STAGER         S          19
# 1951                                Conflict         S          19
# 2839                                    MilK         S          20
# 2834                   Energy Synergy Matrix         S          20
# 2851                                 Acquire         S          20
# 2676                               Queencard         S          20
# 2410                                 BOOOM!!         S          20
# 2286                   Gashina - FULL SONG -         S          20
# 1659                          Crossing Delta         S          20
# 93                                Mad5cience         S          20
# 126                            Super Fantasy         S          20
# 193                           Move That Body         S          20
# 889             Utsushiyo No Kaze feat. Kana         S          20
# 1580                          Kimchi Fingers         S          20
# 2941                               Big Daddy         S          21
# 2689                                    BOCA         S          21
# 1423                                    1949         S          21
# 2968                           TRICKL4SH 220         S          21
# 2369                         Galaxy Collapse         S          22
# 1892                              Club Night         S          22
# 2256  Papasito (feat.  KuTiNA) - FULL SONG -         S          22
# 1942                                F(R)IEND         S          23
# 2207                                    Re \         S          23
# 2449                                 KUGUTSU         S          23
# 184                       Annihilator Method         S          23
# 1424                                    1949         S          23
# 1464                  Telling Fortune Flower         S          23
# 1479                    HEART RABBIT COASTER         S          23
# 688                              Avalanquiem         S          23
# 801                                  Further         S          24
# 952                                   ESCAPE         S          24
# 1350                                 Leather         S          24
# 2379                     Fracture Temporelle         S          24
# 794                           Shub Niggurath         S          24
# 2588                           Neo Catharsis         S          25
# 2346                               Ultimatum         S          25
#
#                                timestamps (QSC-ZSE-QSC)
# 731                                    [26.451, 26.108]
# 2152                                   [35.525, 35.925]
# 512                                            [70.987]
# 2282                                 [189.212, 189.569]
# 1409                                   [102.64, 101.24]
# 2822                                   [60.692, 63.218]
# 635   [77.169, 80.597, 84.026, 75.455, 78.883, 82.31...
# 73                                     [41.293, 41.645]
# 331                                    [94.962, 94.609]
# 513                     [26.073, 70.987, 23.33, 30.187]
# 177                                    [78.046, 79.546]
# 2419                    [32.651, 36.08, 30.937, 34.366]
# 1134                   [70.366, 72.021, 70.573, 71.814]
# 2392                   [59.836, 62.921, 60.179, 62.579]
# 1376                           [56.452, 57.952, 56.827]
# 2886                                            [77.57]
# 2896                                          [104.439]
# 1951                                           [87.104]
# 2839                                     [73.24, 66.84]
# 2834                          [60.336, 120.805, 60.055]
# 2851                                  [94.517, 116.388]
# 2676                                           [87.993]
# 2410  [38.335, 50.71, 62.335, 86.71, 38.71, 50.335, ...
# 2286                                   [150.57, 150.41]
# 1659  [96.393, 97.393, 105.393, 106.06, 101.727, 102...
# 93                                     [30.211, 30.442]
# 126                            [27.773, 77.842, 31.083]
# 193                                    [60.038, 59.624]
# 889    [39.107, 67.528, 97.725, 39.304, 67.824, 97.528]
# 1580                                   [76.664, 76.506]
# 2941                                           [25.659]
# 2689  [27.97, 102.82, 105.67, 107.02, 110.62, 111.67...
# 1423                                   [29.094, 70.617]
# 2968                                          [118.394]
# 2369                                   [82.702, 82.933]
# 1892                                   [31.234, 25.587]
# 2256                                 [214.339, 221.839]
# 1942                                   [11.151, 11.001]
# 2207                                    [44.95, 44.808]
# 2449                                   [64.798, 62.616]
# 184                                    [40.716, 40.873]
# 1424                                           [70.617]
# 1464                                             [92.2]
# 1479                                     [95.64, 95.49]
# 688       [2.776, 49.576, 50.262, 3.462, 49.404, 50.09]
# 801                    [28.835, 78.628, 29.144, 78.319]
# 952                            [92.943, 92.806, 93.352]
# 1350                                     [27.93, 28.23]
# 2379                                           [42.702]
# 794                    [46.517, 64.108, 46.653, 63.971]
# 2588                                           [43.275]
# 2346                                  [28.952, 100.879]

# %% [markdown]
# ### Pattern Search Example (Double)

# %%
pattern = 'Z-Q-S-E-C-V-R-G-Y-N' # Double M-run.
col = f'timestamps ({pattern})'

# The search function requires the step type and chart as inputs as well as the pattern,
# so we apply the following lambda function to search each stepchart in the data frame.
df_d = df.loc[df['Step Type'] == 'D', :].copy()
df_d[col] = df_d.apply(lambda row: searcher.search(
    row['Step Type'],
    row['Steps'],
    pattern,
    0,
    1
), axis=1)

# Create new column showing timestamps where pattern is found.
df_d.loc[
    df_d[col].apply(len) > 0, # exclude stepcharts with 0 matches.
    ['Song Title', 'Step Type', 'Difficulty', col]
].sort_values('Difficulty')
# Out:
#                                             Song Title Step Type  Difficulty  \
# 669                                      Break It Down         D          13
# 1432                                             JANUS         D          14
# 1575                                  Tales of Pumpnia         D          14
# 1496                                           Skeptic         D          14
# 1089                                         Energetic         D          16
# 810        The Quick Brown Fox Jumps Over The Lazy Dog         D          16
# 721                        Super Fantasy - SHORT CUT -         D          17
# 67                                             Requiem         D          18
# 1106                                           PICK ME         D          18
# 962                                      Waltz of Doge         D          18
# 1090                                         Energetic         D          19
# 2051                                              Loki         D          20
# 1214                                Time Attack <Blue>         D          20
# 6                                              Nemesis         D          20
# 224                                           Red Snow         D          21
# 1386                            Hyperion - SHORT CUT -         D          21
# 613                                              PRIME         D          21
# 491                                         Imprinting         D          21
# 1153                                                V3         D          21
# 321                                              Loner         D          22
# 804                                            Further         D          22
# 1351                                           Leather         D          22
# 1497                                           Skeptic         D          22
# 1671                                           Jogging         D          22
# 1870                                     King of Sales         D          23
# 1379                          Death Moon - SHORT CUT -         D          23
# 2183                                        Repentance         D          23
# 1397                                  Wedding Crashers         D          23
# 2582                                          Imperium         D          23
# 1590                                  Orbit Stabilizer         D          23
# 2852                                           Acquire         D          23
# 2174                                        Harmagedon         D          24
# 151                                           Hyacinth         D          24
# 2012                                           Uranium         D          24
# 843                                          Sarabande         D          24
# 2932                                           Halcyon         D          24
# 948                                          Awakening         D          24
# 492                                         Imprinting         D          24
# 1055                                        Good Night         D          24
# 2691                                              BOCA         D          25
# 2583                                          Imperium         D          25
# 2438                                             Jupin         D          25
# 2347                                         Ultimatum         D          25
# 1498                                           Skeptic         D          25
# 1474                                      Nyarlathotep         D          25
# 2891                                              PUPA         D          25
# 2313  Can-can ~Orpheus in The Party Mix~ - SHORT CUT -         D          25
# 2252                          Good Night - FULL SONG -         D          26
# 2242                            PARADOXX - SHORT CUT -         D          26
# 2184                                        Repentance         D          26
# 2381                               Fracture Temporelle         D          26
# 796                                     Shub Niggurath         D          26
# 955                                             ESCAPE         D          26
# 401                                          Achluoias         D          26
# 2615                                       CHAOS AGAIN         D          26
# 2248                                         Brown Sky         D          26
# 2348                                         Ultimatum         D          27
# 2454                                           KUGUTSU         D          27
# 1347                                      Shub Sothoth         D          27
#
#                        timestamps (Z-Q-S-E-C-V-R-G-Y-N)
# 669                                            [67.064]
# 1432                                           [77.154]
# 1575                                            [97.12]
# 1496                                           [12.664]
# 1089                                           [85.504]
# 810                                            [85.866]
# 721                                            [38.744]
# 67                                             [79.957]
# 1106                                           [75.963]
# 962                                             [99.53]
# 1090                                           [85.504]
# 2051                                           [82.019]
# 1214                                  [16.154, 113.213]
# 6                                              [98.227]
# 224                                    [57.119, 55.796]
# 1386                                    [33.392, 40.53]
# 613                                             [96.32]
# 491                                            [98.018]
# 1153                                           [78.741]
# 321                                              [99.6]
# 804                                           [112.572]
# 1351                                           [160.83]
# 1497                                           [91.449]
# 1671                                            [13.03]
# 1870                                   [70.303, 69.403]
# 1379  [59.921, 61.608, 63.296, 59.077, 60.765, 62.45...
# 2183                                           [98.286]
# 1397                                          [102.242]
# 2582                                           [96.796]
# 1590                                           [85.972]
# 2852                                           [68.194]
# 2174                                           [81.644]
# 151                                           [104.424]
# 2012                                           [93.826]
# 843                                            [67.315]
# 2932                                           [94.292]
# 948                                            [52.818]
# 492                                           [113.104]
# 1055                                           [99.157]
# 2691                                           [114.52]
# 2583                           [52.916, 24.209, 54.296]
# 2438                                     [80.426, 83.2]
# 2347                                           [78.157]
# 1498                                           [86.952]
# 1474                                            [101.4]
# 2891                                          [115.293]
# 2313  [33.771, 35.156, 36.541, 37.925, 15.31, 31.233...
# 2252                                           [158.52]
# 2242                                           [30.405]
# 2184                                   [97.536, 98.286]
# 2381                                           [97.142]
# 796                                            [86.335]
# 955                                     [85.647, 86.67]
# 401                                            [94.786]
# 2615                                          [123.217]
# 2248                            [76.66, 105.91, 133.96]
# 2348                                   [78.254, 87.685]
# 2454                                 [107.957, 106.934]
# 1347                                          [127.989]
